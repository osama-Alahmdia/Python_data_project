# %%
import pandas as pd
import ast
from datasets import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns

dataset = load_dataset('lukebarousse/data_jobs')
df =dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df_DA_US=df[(df['job_title']=='Data Analyst')&(df['job_country']=='United States')].copy()

# %%
df_DA_US['job_posted_month_no']=df_DA_US['job_posted_date'].dt.month

# %%
df_DA_US_explode=df_DA_US.explode('job_skills')

# %%
df_DA_US_pivot=df_DA_US_explode.pivot_table(index='job_posted_month_no',columns='job_skills',aggfunc='size',fill_value=0)

df_DA_US_pivot.loc['Total']=df_DA_US_pivot.sum()

df_DA_US_pivot= df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_US_pivot=df_DA_US_pivot.drop('Total')

# %%
df_DA_US_pivot= df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_US_pivot=df_DA_US_pivot.drop('Total')

df_DA_US_pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_DA_US_pivot= df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]
#       2
#       3 df_DA_US_pivot=df_DA_US_pivot.drop('Total')
#       4
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\generic.py:4241, in NDFrame.xs(self, key, axis, level, drop_level)
#    4237                     new_index = index[loc : loc + 1]
#    4238                 else:
#    4239                     new_index = index[loc]
#    4240         else:
# -> 4241             loc = index.get_loc(key)
#    4242
#    4243             if isinstance(loc, np.ndarray):
#    4244                 if loc.dtype == np.bool_:
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Total'

# %%
df_DA_US_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month_no
# 1                         12         0       53        0        1    0     0
# 2                         13         0       34        1        2    0     0
# 3                         11         0       41        1        3    0     0
# 4                          5         0       57        1        0    0     0
# 5                          6         1       35        0        3    0     0
# 6                         10         3       33        1        1    0     2
# 7                         13         0       33        0        1    0     0
# 8                          9         2       29        0        0    0     0
# 9                          7         0       19        1        0    1     0
# 10                         7         3       16        1        0    0     1
# 11                         6         0       24        0        0    0     0
# 12                         4         0       16        3        1    0     1
#
# job_skills           asana  asp.net  assembly  ...  vmware  vue  watson  \
# job_posted_month_no                            ...
# 1                        1        1         8  ...       2    0       0
# 2                        4        2         7  ...       0    5       1
# 3                        6        2         4  ...       1    2       0
# 4                        1        0         1  ...       2    0       0
# 5                        1        2         1  ...       0    0       0
# 6                        0        0         4  ...       1    0       0
# 7                        1        0         4  ...       0    0       0
# 8                        0        0        14  ...       0    0       0
# 9                        2        0         0  ...       2    0       0
# 10                       0        1         3  ...       0    0       0
# 11                       0        2         3  ...       0    0       1
# 12                       1        0         6  ...       0    1       0
#
# job_skills           webex  windows  wire  word  workfront  yarn  zoom
# job_posted_month_no
# 1                        2       10     0   169          0     0     3
# 2                        1       21     1   128          0     0     2
# 3                        2       14     3   142          0     0     4
# 4                        1       24     4   143          1     0     2
# 5                        1       20     0    92          0     0     1
# 6                        0       15     2   126          0     0     2
# 7                        0       15     2   101          0     1     0
# 8                        1       15     1   112          0     0     5
# 9                        0       11     0    65          0     0     2
# 10                       0       10     0    76          0     0     1
# 11                       3        6     0    61          0     0     1
# 12                       0        8     0    85          2     0     5
#
# [12 rows x 188 columns]

# %%
DA_total=df_DA_US.groupby('job_posted_month_no').size()

# %%
df_DA_US_percent=df_DA_US_pivot.div(DA_total/100,axis=0)

df_DA_US_percent
# Out:
# job_skills                 sql      excel    tableau     python   power bi  \
# job_posted_month_no
# 1                    62.665198  43.006608  35.572687  29.129956  17.951542
# 2                    60.903427  42.367601  31.775701  29.439252  23.520249
# 3                    58.883994  42.584435  33.994126  29.368576  20.337739
# 4                    61.723886  42.147553  33.747261  30.752374  21.329438
# 5                    61.072664  42.387543  31.747405  29.065744  21.712803
# 6                    61.474731  40.679370  32.725766  32.808616  22.535211
# 7                    58.638743  45.130890  30.994764  30.575916  19.895288
# 8                    55.445545  45.332390  33.946252  32.531825  20.650636
# 9                    56.658879  39.252336  32.359813  29.556075  21.378505
# 10                   55.489022  34.231537  30.738523  26.946108  20.658683
# 11                   55.660377  34.316038  29.009434  27.594340  19.811321
# 12                   52.998776  39.657283  29.865361  32.925337  21.175031
#
# job_skills                 sas          r       word  powerpoint    oracle  \
# job_posted_month_no
# 1                    21.696035  18.612335   9.306167    9.691630  9.030837
# 2                    21.028037  18.146417   9.968847   10.124611  7.710280
# 3                    22.026432  17.694567  10.425844    9.324523  7.856094
# 4                    18.845873  17.384953  10.445581    9.715121  8.911614
# 5                    17.820069  18.944637   7.958478   10.294118  8.477509
# 6                    16.735708  20.878210  10.439105    9.610605  8.202154
# 7                    19.057592  19.685864  10.575916   10.575916  6.492147
# 8                    19.236209  22.701556   7.920792    9.405941  6.930693
# 9                    17.523364  18.341121   7.593458    6.191589  7.827103
# 10                   14.970060  15.369261   7.584830    7.085828  6.586826
# 11                   17.216981  14.150943   7.193396    6.721698  6.485849
# 12                   21.297430  20.685435  10.403917    8.445532  5.140759
#
# job_skills           ...   mariadb     mxnet   next.js  ringcentral  \
# job_posted_month_no  ...
# 1                    ...  0.000000  0.000000  0.000000     0.055066
# 2                    ...  0.000000  0.000000  0.000000     0.000000
# 3                    ...  0.000000  0.000000  0.000000     0.000000
# 4                    ...  0.000000  0.000000  0.000000     0.000000
# 5                    ...  0.086505  0.000000  0.000000     0.000000
# 6                    ...  0.000000  0.000000  0.000000     0.000000
# 7                    ...  0.000000  0.000000  0.104712     0.000000
# 8                    ...  0.000000  0.000000  0.000000     0.000000
# 9                    ...  0.000000  0.000000  0.000000     0.000000
# 10                   ...  0.000000  0.000000  0.000000     0.000000
# 11                   ...  0.000000  0.000000  0.000000     0.000000
# 12                   ...  0.000000  0.122399  0.000000     0.000000
#
# job_skills           sqlserver    svelte    theano   tidyr  symphony      yarn
# job_posted_month_no
# 1                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 2                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 3                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 4                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 5                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 6                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 7                     0.104712  0.000000  0.000000  0.0000  0.000000  0.104712
# 8                     0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 9                     0.000000  0.000000  0.000000  0.0000  0.116822  0.000000
# 10                    0.000000  0.000000  0.000000  0.0998  0.000000  0.000000
# 11                    0.000000  0.000000  0.000000  0.0000  0.000000  0.000000
# 12                    0.000000  0.122399  0.122399  0.0000  0.000000  0.000000
#
# [12 rows x 188 columns]

# %%
df_DA_US_percent = df_DA_US_percent.reset_index()
df_DA_US_percent['job_posted_month'] = df_DA_US_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month')
df_DA_US_percent = df_DA_US_percent.drop(columns='job_posted_month_no')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'job_posted_month_no'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 df_DA_US_percent = df_DA_US_percent.reset_index()
# ----> 2 df_DA_US_percent['job_posted_month'] = df_DA_US_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
#       3 df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month')
#       4 df_DA_US_percent = df_DA_US_percent.drop(columns='job_posted_month_no')
#       5
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\anaconda3\envs\Python_proj\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'job_posted_month_no'

# %%
skills = ['sql', 'excel', 'tableau', 'python','power bi']

plt.figure(figsize=(10, 6))

sns.lineplot(data=df_DA_US_percent[skills],dashes=False,palette='tab10')
sns.set_theme(style='ticks')

plt.title('Trending Top Skills for Data Analysts in the US')
plt.ylabel('Likelihood in Job Posting')
plt.legend().remove()
sns.despine()

from matplotlib.ticker import PercentFormatter
ax =plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))

plt.xlim(-0.5,12.5)
 
for skill in skills:
    last_value = df_DA_US_percent[skill].iloc[-1]
    plt.text(11.1, last_value, f' {skill}', va='center')
plt.tight_layout()
plt.show()

# %%
# Out:
# job_skills job_posted_month  index        sql      excel    tableau  \
# 0                       Jan      0  62.665198  43.006608  35.572687
# 1                       Feb      1  60.903427  42.367601  31.775701
# 2                       Mar      2  58.883994  42.584435  33.994126
# 3                       Apr      3  61.723886  42.147553  33.747261
# 4                       May      4  61.072664  42.387543  31.747405
# 5                       Jun      5  61.474731  40.679370  32.725766
# 6                       Jul      6  58.638743  45.130890  30.994764
# 7                       Aug      7  55.445545  45.332390  33.946252
# 8                       Sep      8  56.658879  39.252336  32.359813
# 9                       Oct      9  55.489022  34.231537  30.738523
# 10                      Nov     10  55.660377  34.316038  29.009434
# 11                      Dec     11  52.998776  39.657283  29.865361
#
# job_skills     python   power bi        sas          r       word  ...  \
# 0           29.129956  17.951542  21.696035  18.612335   9.306167  ...
# 1           29.439252  23.520249  21.028037  18.146417   9.968847  ...
# 2           29.368576  20.337739  22.026432  17.694567  10.425844  ...
# 3           30.752374  21.329438  18.845873  17.384953  10.445581  ...
# 4           29.065744  21.712803  17.820069  18.944637   7.958478  ...
# 5           32.808616  22.535211  16.735708  20.878210  10.439105  ...
# 6           30.575916  19.895288  19.057592  19.685864  10.575916  ...
# 7           32.531825  20.650636  19.236209  22.701556   7.920792  ...
# 8           29.556075  21.378505  17.523364  18.341121   7.593458  ...
# 9           26.946108  20.658683  14.970060  15.369261   7.584830  ...
# 10          27.594340  19.811321  17.216981  14.150943   7.193396  ...
# 11          32.925337  21.175031  21.297430  20.685435  10.403917  ...
#
# job_skills   mariadb     mxnet   next.js  ringcentral  sqlserver    svelte  \
# 0           0.000000  0.000000  0.000000     0.055066   0.000000  0.000000
# 1           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 2           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 3           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 4           0.086505  0.000000  0.000000     0.000000   0.000000  0.000000
# 5           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 6           0.000000  0.000000  0.104712     0.000000   0.104712  0.000000
# 7           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 8           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 9           0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 10          0.000000  0.000000  0.000000     0.000000   0.000000  0.000000
# 11          0.000000  0.122399  0.000000     0.000000   0.000000  0.122399
#
# job_skills    theano   tidyr  symphony      yarn
# 0           0.000000  0.0000  0.000000  0.000000
# 1           0.000000  0.0000  0.000000  0.000000
# 2           0.000000  0.0000  0.000000  0.000000
# 3           0.000000  0.0000  0.000000  0.000000
# 4           0.000000  0.0000  0.000000  0.000000
# 5           0.000000  0.0000  0.000000  0.000000
# 6           0.000000  0.0000  0.000000  0.104712
# 7           0.000000  0.0000  0.000000  0.000000
# 8           0.000000  0.0000  0.116822  0.000000
# 9           0.000000  0.0998  0.000000  0.000000
# 10          0.000000  0.0000  0.000000  0.000000
# 11          0.122399  0.0000  0.000000  0.000000
#
# [12 rows x 190 columns]
