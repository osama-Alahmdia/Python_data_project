# %%
import pandas as pd
import ast
from datasets import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns

dataset = load_dataset('lukebarousse/data_jobs')
df =dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df_DA_US=df[(df['job_title_short']=='Data Analyst')&(df['job_country']=='United States')].copy()

# %%
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

df_DA_US_exploded = df_DA_US.explode('job_skills')

df_DA_US_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#      salary_year_avg job_skills
# 109          89000.0     python
# 109          89000.0          r
# 109          89000.0    alteryx
# 109          89000.0    tableau
# 180          90250.0      excel

# %%
df_DA_US_exploded.groupby('job_skills')['salary_year_avg'].agg(['count','median']).sort_values(by='count',ascending=False)
# Out:
#             count    median
# job_skills
# sql          2508   91000.0
# excel        1808   84392.0
# python       1431   97500.0
# tableau      1364   92875.0
# sas           926   90000.0
# ...           ...       ...
# theano          1  100000.0
# typescript      1   65000.0
# vmware          1  147500.0
# vue             1   65000.0
# wrike           1   75000.0
#
# [170 rows x 2 columns]

# %%
df_DA_skills = df_DA_US_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_US)

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

Skill_percent=5

df_DA_skills_high_demand=df_DA_skills[df_DA_skills['skill_percent']>Skill_percent]

df_DA_skills_high_demand
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                2508       91000.00      57.655172
# excel              1808       84392.00      41.563218
# python             1431       97500.00      32.896552
# tableau            1364       92875.00      31.356322
# sas                 926       90000.00      21.287356
# r                   893       92500.00      20.528736
# power bi            838       90000.00      19.264368
# powerpoint          462       85000.00      10.620690
# word                461       81194.75      10.597701
# sql server          286       92500.00       6.574713
# oracle              274       96923.75       6.298851
# go                  224       90000.00       5.149425

# %%
from adjustText import adjust_text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from adjustText import adjust_text
#
# ModuleNotFoundError: No module named 'adjustText'

# %%
from adjustText import adjust_text

df_DA_skills_high_demand.plot(kind='scatter', x='skill_percent', y='median_salary')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analysis Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysis in the US')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot
plt.tight_layout()
plt.show()

# %%
# !pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjusttext-1.4.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from adjustText) (2.4.6)
# Requirement already satisfied: matplotlib in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from adjustText) (3.11.0)
# Collecting scipy (from adjustText)
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\HUAWEI\anaconda3\envs\Python_proj\Lib\site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# Downloading adjusttext-1.4.0-py3-none-any.whl (13 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.6 MB 670.4 kB/s eta 0:00:54
#     --------------------------------------- 0.8/36.6 MB 817.9 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/36.6 MB 867.1 kB/s eta 0:00:42
#    - -------------------------------------- 1.0/36.6 MB 867.1 kB/s eta 0:00:42
#    - -------------------------------------- 1.3/36.6 MB 817.9 kB/s eta 0:00:44
#    - -------------------------------------- 1.6/36.6 MB 855.6 kB/s eta 0:00:41
#    -- ------------------------------------- 1.8/36.6 MB 867.5 kB/s eta 0:00:41
#    -- ------------------------------------- 1.8/36.6 MB 867.5 kB/s eta 0:00:41
#    -- ------------------------------------- 2.1/36.6 MB 889.5 kB/s eta 0:00:39
#    -- ------------------------------------- 2.1/36.6 MB 889.5 kB/s eta 0:00:39
#    -- ------------------------------------- 2.4/36.6 MB 843.9 kB/s eta 0:00:41
#    -- ------------------------------------- 2.6/36.6 MB 853.0 kB/s eta 0:00:40
#    -- ------------------------------------- 2.6/36.6 MB 853.0 kB/s eta 0:00:40
#    --- ------------------------------------ 2.9/36.6 MB 818.2 kB/s eta 0:00:42
#    --- ------------------------------------ 2.9/36.6 MB 818.2 kB/s eta 0:00:42
#    --- ------------------------------------ 3.1/36.6 MB 802.3 kB/s eta 0:00:42
#    --- ------------------------------------ 3.4/36.6 MB 815.0 kB/s eta 0:00:41
#    ------------------------------------- -- 34.1/36.6 MB 611.5 kB/s eta 0:00:05
#    ------------------------------------- -- 34.3/36.6 MB 603.3 kB/s eta 0:00:04
#    ------------------------------------- -- 34.3/36.6 MB 603.3 kB/s eta 0:00:04
#    ------------------------------------- -- 34.3/36.6 MB 603.3 kB/s eta 0:00:04
#    ------------------------------------- -- 34.6/36.6 MB 599.5 kB/s eta 0:00:04
#    ------------------------------------- -- 34.6/36.6 MB 599.5 kB/s eta 0:00:04
#    ------------------------------------- -- 34.6/36.6 MB 599.5 kB/s eta 0:00:04
#    -------------------------------------- - 34.9/36.6 MB 595.7 kB/s eta 0:00:03
#    -------------------------------------- - 34.9/36.6 MB 595.7 kB/s eta 0:00:03
#    -------------------------------------- - 34.9/36.6 MB 595.7 kB/s eta 0:00:03
#    -------------------------------------- - 34.9/36.6 MB 595.7 kB/s eta 0:00:03
#    -------------------------------------- - 34.9/36.6 MB 595.7 kB/s eta 0:00:03
#    -------------------------------------- - 35.1/36.6 MB 585.7 kB/s eta 0:00:03
#    -------------------------------------- - 35.1/36.6 MB 585.7 kB/s eta 0:00:03
#    -------------------------------------- - 35.4/36.6 MB 580.6 kB/s eta 0:00:03
#    -------------------------------------- - 35.4/36.6 MB 580.6 kB/s eta 0:00:03
#    -------------------------------------- - 35.4/36.6 MB 580.6 kB/s eta 0:00:03
#    -------------------------------------- - 35.4/36.6 MB 580.6 kB/s eta 0:00:03
#    -------------------------------------- - 35.7/36.6 MB 572.5 kB/s eta 0:00:02
#    -------------------------------------- - 35.7/36.6 MB 572.5 kB/s eta 0:00:02
#    -------------------------------------- - 35.7/36.6 MB 572.5 kB/s eta 0:00:02
#    -------------------------------------- - 35.7/36.6 MB 572.5 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.6 MB 561.0 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.6 MB 561.0 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.6 MB 561.0 kB/s eta 0:00:02
#    ---------------------------------------  35.9/36.6 MB 561.0 kB/s eta 0:00:02
#    ---------------------------------------  36.2/36.6 MB 549.8 kB/s eta 0:00:01
#    ---------------------------------------  36.2/36.6 MB 549.8 kB/s eta 0:00:01
#    ---------------------------------------  36.2/36.6 MB 549.8 kB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 544.6 kB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 544.6 kB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 539.0 kB/s  0:01:04
# Installing collected packages: scipy, adjustText
#
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 2/2 [adjustText]
#
# Successfully installed adjustText-1.4.0 scipy-1.17.1

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['tableau',
#   'excel',
#   'looker',
#   'microstrategy',
#   'ssrs',
#   'msaccess',
#   'word',
#   'datarobot',
#   'ssis',
#   'nuix',
#   'dax',
#   'spss',
#   'powerpoint',
#   'alteryx',
#   'spreadsheet',
#   'powerbi',
#   'outlook',
#   'sharepoint',
#   'cognos',
#   'visio',
#   'splunk',
#   'power bi',
#   'esquisse',
#   'sheets',
#   'sap',
#   'qlik',
#   'ms access',
#   'sas'],
#  'programming': ['matlab',
#   'go',
#   'sas',
#   'delphi',
#   'erlang',
#   't-sql',
#   'visualbasic',
#   'julia',
#   'php',
#   'java',
#   'groovy',
#   'nosql',
#   'lua',
#   'crystal',
#   'clojure',
#   'css',
#   'haskell',
#   'python',
#   'sass',
#   'mongo',
#   'html',
#   'scala',
#   'objective-c',
#   'shell',
#   'apl',
#   'lisp',
#   'rust',
#   'vba',
#   'ocaml',
#   'vb.net',
#   'c#',
#   'cobol',
#   'pascal',
#   'solidity',
#   'javascript',
#   'perl',
#   'no-sql',
#   'fortran',
#   'ruby',
#   'typescript',
#   'r',
#   'dart',
#   'golang',
#   'kotlin',
#   'c',
#   'bash',
#   'assembly',
#   'swift',
#   'powershell',
#   'sql',
#   'elixir',
#   'mongodb',
#   'c++',
#   'visual basic',
#   'f#'],
#  'cloud': ['vmware',
#   'aws',
#   'ibm cloud',
#   'openstack',
#   'oracle',
#   'bigquery',
#   'watson',
#   'azure',
#   'snowflake',
#   'databricks',
#   'digitalocean',
#   'linode',
#   'firebase',
#   'aurora',
#   'colocation',
#   'ovh',
#   'heroku',
#   'gcp',
#   'redshift'],
#  'libraries': ['capacitor',
#   'hadoop',
#   'spark',
#   'react',
#   'gdpr',
#   'keras',
#   'dlib',
#   'qt',
#   'hugging face',
#   'selenium',
#   'huggingface',
#   'seaborn',
#   'matplotlib',
#   'dplyr',
#   'rshiny',
#   'pytorch',
#   'theano',
#   'mlpack',
#   'pandas',
#   'pyspark',
#   'opencv',
#   'shogun',
#   'tidyverse',
#   'kafka',
#   'xamarin',
#   'gtx',
#   'jupyter',
#   'airflow',
#   'mlr',
#   'cordova',
#   'numpy',
#   'mxnet',
#   'nltk',
#   'scikit-learn',
#   'graphql',
#   'electron',
#   'ggplot2',
#   'tidyr',
#   'plotly',
#   'tensorflow',
#   'ionic',
#   'chainer',
#   'flutter',
#   'spring'],
#  'other': ['github',
#   'kubernetes',
#   'terminal',
#   'bitbucket',
#   'chef',
#   'puppet',
#   'yarn',
#   'pulumi',
#   'homebrew',
#   'docker',
#   'unity',
#   'terraform',
#   'atlassian',
#   'unreal',
#   'npm',
#   'svn',
#   'flow',
#   'gitlab',
#   'ansible',
#   'codecommit',
#   'jenkins',
#   'git'],
#  'databases': ['cassandra',
#   'sql server',
#   'sqlite',
#   'elasticsearch',
#   'dynamodb',
#   'db2',
#   'couchbase',
#   'mariadb',
#   'firestore',
#   'couchdb',
#   'sqlserver',
#   'postgresql',
#   'redis',
#   'firebase',
#   'mongodb',
#   'neo4j',
#   'mysql'],
#  'os': ['unix',
#   'fedora',
#   'debian',
#   'centos',
#   'kali',
#   'ubuntu',
#   'wsl',
#   'windows',
#   'macos',
#   'arch',
#   'linux',
#   'suse',
#   'redhat'],
#  'async': ['workfront',
#   'clickup',
#   'confluence',
#   'jira',
#   'wimi',
#   'microsoft lists',
#   'planner',
#   'monday.com',
#   'asana',
#   'wrike',
#   'dingtalk',
#   'smartsheet',
#   'airtable',
#   'notion',
#   'trello'],
#  'webframeworks': ['vue',
#   'angular.js',
#   'nuxt.js',
#   'laravel',
#   'asp.netcore',
#   'blazor',
#   'phoenix',
#   'symfony',
#   'fastify',
#   'vue.js',
#   'react.js',
#   'angular',
#   'deno',
#   'rubyon rails',
#   'flask',
#   'node',
#   'django',
#   'next.js',
#   'jquery',
#   'drupal',
#   'play framework',
#   'fastapi',
#   'ruby',
#   'ember.js',
#   'ruby on rails',
#   'svelte',
#   'gatsby',
#   'asp.net core',
#   'node.js',
#   'express',
#   'asp.net'],
#  'sync': ['zoom',
#   'webex',
#   'symphony',
#   'wire',
#   'ringcentral',
#   'slack',
#   'twilio',
#   'mattermost',
#   'google chat',
#   'rocketchat',
#   'unify',
#   'microsoft teams']}

# %%
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology           skills
# 0   analyst_tools          tableau
# 0   analyst_tools            excel
# 0   analyst_tools           looker
# 0   analyst_tools    microstrategy
# 0   analyst_tools             ssrs
# ..            ...              ...
# 9            sync       mattermost
# 9            sync      google chat
# 9            sync       rocketchat
# 9            sync            unify
# 9            sync  microsoft teams
#
# [256 rows x 2 columns]

# %%
df_plot=df_DA_skills_high_demand.merge(df_technology,left_on='job_skills',right_on='skills')

# %%
from adjustText import adjust_text

#df_plot.plot(kind='scatter', x='skill_percent', y='median_salary')

sns.scatterplot(
    data=df_plot,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analysis Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysis in the US')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot
plt.tight_layout()
plt.show()
